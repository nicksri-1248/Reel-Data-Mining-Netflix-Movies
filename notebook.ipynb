# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like

# %%
netflix_df
# Out:
#      show_id     type       title           director  \
# 0         s2    Movie        7:19  Jorge Michel Grau
# 1         s3    Movie       23:59       Gilbert Chan
# 2         s4    Movie           9        Shane Acker
# 3         s5    Movie          21     Robert Luketic
# 4         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 4807   s7779    Movie  Zombieland    Ruben Fleischer
# 4808   s7781    Movie         Zoo       Shlok Sharma
# 4809   s7782    Movie        Zoom       Peter Hewitt
# 4810   s7783    Movie        Zozo        Josef Fares
# 4811   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast        country  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# ### Filter the data for movies released in the 1990s
#
# You'll want to subset the DataFrame to keep only the movies and then filter the years so that you are working with rows where the release year is between 1990 and 1999.

# %%
netflix_movie_1990s_df = netflix_df[(netflix_df["type"] == "Movie") & (netflix_df["release_year"] >= 1990) & (netflix_df["release_year"] <= 1999)]
netflix_movie_1990s_df
# Out:
#      show_id   type                            title            director  \
# 6         s8  Movie                              187      Kevin Reynolds
# 118     s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 145     s211  Movie           A Night at the Roxbury    John Fortenberry
# 167     s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 194     s274  Movie                     Aashik Awara         Umesh Mehra
# ...      ...    ...                              ...                 ...
# 4672   s7536  Movie                      West Beirut        Ziad Doueiri
# 4689   s7571  Movie      What's Eating Gilbert Grape     Lasse Hallström
# 4718   s7624  Movie                   Wild Wild West    Barry Sonnenfeld
# 4746   s7682  Movie                       Wyatt Earp     Lawrence Kasdan
# 4756   s7695  Movie                      Yaar Gaddar         Umesh Mehra
#
#                                                    cast        country  \
# ...

# %% [markdown]
# ### Find the most frequent movie duration
#
# Visualize the data to view the distributions of durations for movies released in the 1990s.

# %%
plt.hist(netflix_movie_1990s_df["duration"])
plt.show()

# %%
most_frequent_movie_duration = 100
print("Most Frequent Movie Duration", most_frequent_movie_duration)
# Out:
# Most Frequent Movie Duration 100

# %% [markdown]
# ### Count the number of short action movies from the 1990s
#
# First, subset the data again to keep only movies with the correct genre. Then, iterate through the data and count the number of movies depending on the condition pf a duration that is less than 90.

# %%
netflix_short_action_movie_1990s = netflix_df[(netflix_df["type"] == "Movie") & (netflix_df["release_year"] >= 1990) & (netflix_df["release_year"] <= 1999) & (netflix_df["genre"] == "Action") & (netflix_df["duration"] <= 90)]
netflix_short_action_movie_1990s
# Out:
#      show_id   type                      title  \
# 1288   s2039  Movie  EVANGELION: DEATH (TRUE)²
# 1698   s2708  Movie                       Hero
# 2328   s3718  Movie          Look Out, Officer
# 2993   s4787  Movie               Passenger 57
# 3297   s5299  Movie        Rumble in the Bronx
# 3806   s6114  Movie        The Bare-Footed Kid
# 3943   s6330  Movie      The End of Evangelion
#
#                             director  \
# 1288                    Hideaki Anno
# 1698                      Corey Yuen
# 2328                      Sze Yu Lau
# 2993                     Kevin Hooks
# 3297                    Stanley Tong
# 3806                      Johnnie To
# 3943  Hideaki Anno, Kazuya Tsurumaki
#
#                                                    cast        country  \
# 1288  Megumi Ogata, Kotono Mitsuishi, Megumi Hayashi...          Japan
# 1698  Takeshi Kaneshiro, Yuen Biao, Valerie Chow, Je...      Hong Kong
# ...

# %%
count = netflix_short_action_movie_1990s.shape[0]

# %%
print("Number of Short Action movies from the 1990s is", count)
# Out:
# Number of Short Action movies from the 1990s is 7

# %%
a = netflix_df["duration"] == 90
netflix_duration_df = netflix_df[(a)]
netflix_duration_df
# Out:
#      show_id   type                                              title  \
# 41       s61  Movie                                       12 ROUND GUN
# 42       s63  Movie                                         13 Cameras
# 50       s76  Movie                                                1BR
# 108     s156  Movie                                   A Champion Heart
# 144     s210  Movie                       A New York Christmas Wedding
# ...      ...    ...                                                ...
# 4633   s7471  Movie  Walt Disney Animation Studios Short Films Coll...
# 4655   s7510  Movie                             We Summon the Darkness
# 4708   s7598  Movie                                         White Girl
# 4713   s7610  Movie                    Who's That Knocking at My Door?
# 4762   s7705  Movie                                         Yellowbird
#
#                                                director  \
# 41                                            Sam Upton
# ...

# %%
print(netflix_df.columns.tolist())
# Out:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'duration', 'description', 'genre']

# %%
features = netflix_df.columns.tolist()
features.remove("show_id")
features.remove("description")
print(features)
# Out:
# ['type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'duration', 'genre']
